# %% [markdown]
# Data set https://huggingface.co/datasets/roneneldan/TinyStories
#
# Copyright Hoa Vu

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import os
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
import random
import pickle
import math
from transformers import AutoTokenizer, BertTokenizer
import gc

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
if not torch.cuda.is_available():
    print("CUDA is not available on your system.")
else:
    # Print the number of CUDA devices
    print(f"Number of CUDA Devices: {torch.cuda.device_count()}\n")

    for i in range(torch.cuda.device_count()):
        print(f"Device {i}:")
        print(f"    Name: {torch.cuda.get_device_name(i)}")
        print(f"    Computational Capability: {torch.cuda.get_device_capability(i)}")
        print(f"    Total Memory: {torch.cuda.get_device_properties(i).total_memory / (1024**2):.2f} MB\n")
# Out:
# Number of CUDA Devices: 1
#
# Device 0:
#     Name: NVIDIA GeForce RTX 3090
#     Computational Capability: (8, 6)
#     Total Memory: 24575.50 MB

# %%
data_path = 'datasets/tiny_stories/'

# %%
filename = 'TinyStoriesV2-GPT4-train.txt'
val_filename = 'TinyStoriesV2-GPT4-valid.txt'

filepath = os.path.join(data_path, filename)
with open(filepath, 'r', encoding='utf-8') as file:
    train_data = file.read()
train_data = train_data.replace('\n', '')
train_data = train_data.split('<|endoftext|>')

val_filepath = os.path.join(data_path, val_filename)
with open(val_filepath, 'r', encoding='utf-8') as file:
    val_data = file.read()
val_data = val_data.replace('\n', '')
val_data = val_data.split('<|endoftext|>')

print(train_data[0])
# Out:
# Once upon a time there was a little boy named Ben. Ben loved to explore the world around him. He saw many amazing things, like beautiful vases that were on display in a store. One day, Ben was walking through the store when he came across a very special vase. When Ben saw it he was amazed!  He said, “Wow, that is a really amazing vase! Can I buy it?” The shopkeeper smiled and said, “Of course you can. You can take it home and show all your friends how amazing it is!”So Ben took the vase home and he was so proud of it! He called his friends over and showed them the amazing vase. All his friends thought the vase was beautiful and couldn't believe how lucky Ben was. And that's how Ben found an amazing vase in the store!

# %%
train_data = pd.DataFrame(train_data, columns=['content'])
val_data = pd.DataFrame(val_data, columns=['content'])

print(train_data.shape)
print(val_data.shape)

print(train_data.head())
# Out:
# (2717700, 1)
# (27631, 1)
#                                              content
# 0  Once upon a time there was a little boy named ...
# 1  Once upon a time, there was a reliable otter n...
# 2  One day, a little boy named Tim went to the pa...
# 3  Once upon a time there was a friendly little b...
# 4  Once upon a time, in a small house, there live...

# %%
from transformers import BertTokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Get the IDs
cls_id = tokenizer.cls_token_id
sep_id = tokenizer.sep_token_id
unk_id = tokenizer.unk_token_id
pad_id = tokenizer.pad_token_id

print("PAD Token ID:", pad_id)
print("UNK Token ID:", unk_id)
print("CLS Token ID:", cls_id)
print("SEP Token ID:", sep_id)
# Out:
# PAD Token ID: 0
# UNK Token ID: 100
# CLS Token ID: 101
# SEP Token ID: 102

# %%
BLOCK_SIZE = 256
VOCAB_SIZE = tokenizer.vocab_size
print('Vocab size is ', VOCAB_SIZE)
# Out:
# Vocab size is  30522

# %%
def get_batch(data, block_size, batch_size):
    x = torch.zeros((batch_size, block_size), dtype=torch.long)
    y = torch.zeros((batch_size, block_size), dtype=torch.long)
    samples = data['content'].sample(n=batch_size)

    for i, sample in enumerate(samples):
        token_ids = tokenizer.encode(sample)
        token_ids = [id for id in token_ids if id != unk_id]
        if len(token_ids) < block_size + 2:
            token_ids = token_ids + [pad_id] * (block_size + 2 - len(token_ids))
        random_start = random.randint(0, len(token_ids) - block_size - 2)
        x[i, :len(token_ids)] = torch.tensor(token_ids[random_start:random_start + block_size], dtype=torch.long)
        y[i, :len(token_ids)] = torch.tensor(token_ids[random_start + 1:random_start + block_size + 1], dtype=torch.long)

    return x, y

a, b = get_batch(train_data, block_size=BLOCK_SIZE, batch_size=1)
print(a.shape, b.shape)
print(tokenizer.decode(a[0].tolist(), skip_special_tokens=False))
print(tokenizer.decode(b[0].tolist(), skip_special_tokens=False))
# Out:
# torch.Size([1, 256]) torch.Size([1, 256])
# [CLS] once upon a time, there was a little boy named tim. tim had an old toy car that he loved a lot. the toy car was very old and didn't go as fast as it used to. tim wanted to improve his toy car so it could go fast again. one day, tim asked his mom to help him improve his toy car. they worked together in silence, fixing the old toy car. they put new wheels on it and painted it a bright color. tim was very happy with the changes they made. now, tim's old toy car was fast again. he played with it every day, racing it around the house. the silence was gone as tim laughed and had fun with his improved toy car. he was so thankful to his mom for helping him make his old toy car better. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]
# once upon a time, there was a little boy named tim. tim had an old toy car that he loved a lot. the toy car was very old and didn't go as fast as it used to. tim wanted to improve his toy car so it could go fast again. one day, tim asked his mom to help him improve his toy car. they worked together in silence, fixing the old toy car. they put new wheels on it and painted it a bright color. tim was very happy with the changes they made. now, tim's old toy car was fast again. he played with it every day, racing it around the house. the silence was gone as tim laughed and had fun with his improved toy car. he was so thankful to his mom for helping him make his old toy car better. [SEP] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]

# %%
N_EMB = 800
N_LAYERS = 6
N_HEADS = 10
DROPOUT = 0.2


def estimate_loss(model, val_data, block_size, batch_size):
    model.eval()
    with torch.no_grad():
        x, y = get_batch(val_data, block_size, batch_size)
        x, y = x.to(device), y.to(device)
        _, loss = model(x, y)
    model.train()
    return loss.item()

def generate_square_subsequent_mask(sz):
    mask = (torch.tril(torch.ones(sz, sz)) == 1).float()
    mask = mask.masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
    return mask

def get_sine_position_encodings(length, dim):
    pos = torch.arange(length, dtype=torch.float32).reshape(-1, 1)
    div_term = torch.exp(torch.arange(0, dim, 2).float() * -(math.log(10000.0) / dim))
    pos_encodings = torch.zeros(length, dim)
    pos_encodings[:, 0::2] = torch.sin(pos * div_term)
    pos_encodings[:, 1::2] = torch.cos(pos * div_term)
    return pos_encodings

class LanguageModel(nn.Module):

    def __init__(self, vocab_size, n_emb, block_size, n_layers, n_heads, dropout=0.2):
        super(LanguageModel, self).__init__()

        self.token_embedding_table = nn.Embedding(vocab_size, n_emb)
        self.position_embedding_table = nn.Embedding(block_size, n_emb)
        self.block_size = block_size

        encoder_layer = nn.TransformerEncoderLayer(d_model=n_emb, nhead=n_heads, dropout=dropout, layer_norm_eps=1e-6)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=n_layers)

        self.feed_forward = nn.Sequential(
            nn.Linear(n_emb, 2 * n_emb),
            nn.ReLU(),
            nn.Linear(2 * n_emb, n_emb)
        )

        self.lm_head = nn.Linear(n_emb, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        token_emb = self.token_embedding_table(idx)
        position_emb = self.position_embedding_table(torch.arange(T, device=device))

        x = token_emb + position_emb
        x_transform = x.clone()
        mask = generate_square_subsequent_mask(T).to(device)

        x_transform = self.transformer_encoder(x_transform.permute(1, 0, 2), mask=mask)
        x_transform = x_transform.permute(1, 0, 2)
        x = x + x_transform

        x = self.feed_forward(x)
        logits = self.lm_head(x)

        if targets is not None:
            B, T, C = logits.shape
            logits = logits.view(B * T, C)
            targets = targets.view(B * T)
            loss = F.cross_entropy(logits, targets)
            return logits, loss
        else:
            return logits, None


    def generate(self, idx, max_new_tokens, temperature=1.0, stop_token=False):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -self.block_size:]
            logits, _ = self.forward(idx_cond)

            # Scale logits by the temperature
            logits = logits[:, -1, :] / temperature

            probs = F.softmax(logits, dim=-1)
            idx_new = torch.multinomial(probs, num_samples=1)
            idx = torch.cat([idx, idx_new], dim=-1)
            if stop_token and idx_new.item() == sep_id:
                break
        return idx

# Create model, optimizer
model = LanguageModel(vocab_size=VOCAB_SIZE, block_size=BLOCK_SIZE, n_emb=N_EMB, n_layers=N_LAYERS, \
    n_heads=N_HEADS, dropout=DROPOUT).to(device)

print(f'Number of parameters {sum(p.numel() for p in model.parameters() if p.requires_grad)}')
# Out:
# C:\Users\hvutr\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\transformer.py:282: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Number of parameters 86709210

# %%
model_path = os.path.join(data_path, "english_tiny_stories_6layers.pth")
model = torch.load(model_path)
# Out:
# datasets/tiny_stories/english_tiny_stories_6layers.pth

# %%
EARLY_STOP = 50
N_EPOCHS = 20000
BATCH_SIZE = 32
LEARNING_RATE = 3e-4
SAVE_FREQ = 500
optimizer = torch.optim.Adam(model.parameters(), lr=LEARNING_RATE)

model_path = os.path.join(data_path, "english_tiny_stories_6layers.pth")

for steps in range(N_EPOCHS):
    model.train()
    xb, yb = get_batch(train_data, block_size=BLOCK_SIZE, batch_size=BATCH_SIZE)
    xb = xb.to(device)
    yb = yb.to(device)
    logits, loss = model(xb, yb)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    # Delete xb, yb and free GPU memory
    del xb, yb
    torch.cuda.empty_cache()

    if steps % 100 == 0:
        print('Step:', steps, 'Training Loss:', loss.item())
        val_loss = estimate_loss(model, val_data, block_size=BLOCK_SIZE, batch_size=BATCH_SIZE)
        print('Validation loss:', val_loss)
    if steps % SAVE_FREQ == 0:
        torch.save(model, model_path)
# Out:
# Step: 0 Training Loss: 1.9710575342178345
# Validation loss: 2.055588960647583
# Step: 100 Training Loss: 1.9694819450378418
# Validation loss: 1.8874846696853638
# Step: 200 Training Loss: 1.871381163597107
# Validation loss: 1.931668996810913
# Step: 300 Training Loss: 1.9949411153793335
# Validation loss: 1.8256757259368896
# Step: 400 Training Loss: 1.8179761171340942
# Validation loss: 1.7700958251953125
# Step: 500 Training Loss: 1.84648859500885
# Validation loss: 2.003999948501587
# Step: 600 Training Loss: 2.053264617919922
# Validation loss: 1.8363125324249268
# Step: 700 Training Loss: 1.6992143392562866
# Validation loss: 1.740901231765747
# Step: 800 Training Loss: 1.7828682661056519
# Validation loss: 1.6546281576156616
# Step: 900 Training Loss: 1.6639729738235474
# Validation loss: 1.7989543676376343
# Step: 1000 Training Loss: 1.7726454734802246
# Validation loss: 1.679582118988037
# Step: 1100 Training Loss: 1.6442790031433105
# Validation loss: 1.7373028993606567
# Step: 1200 Training Loss: 1.5917258262634277
# Validation loss: 1.6974471807479858
# Step: 1300 Training Loss: 1.6683127880096436
# Validation loss: 1.4359266757965088
# Step: 1400 Training Loss: 1.5596693754196167
# Validation loss: 1.4094417095184326
# Step: 1500 Training Loss: 1.5441901683807373
# Validation loss: 1.449723243713379
# Step: 1600 Training Loss: 1.4944242238998413
# Validation loss: 1.595405101776123
# Step: 1700 Training Loss: 1.5097546577453613
# Validation loss: 1.6837397813796997
# Step: 1800 Training Loss: 1.6336066722869873
# Validation loss: 1.4869458675384521
# Step: 1900 Training Loss: 1.3962345123291016
# Validation loss: 1.350875973701477
# Step: 2000 Training Loss: 1.577463984489441
# Validation loss: 1.5336182117462158
# Step: 2100 Training Loss: 1.4596279859542847
# Validation loss: 1.495064616203308
# Step: 2200 Training Loss: 1.5995362997055054
# Validation loss: 1.447455644607544
# Step: 2300 Training Loss: 1.4175466299057007
# Validation loss: 1.506611943244934
# Step: 2400 Training Loss: 1.428383231163025
# Validation loss: 1.5097856521606445
# Step: 2500 Training Loss: 1.6271106004714966
# Validation loss: 1.495733618736267
# Step: 2600 Training Loss: 1.3691456317901611
# Validation loss: 1.4666297435760498
# Step: 2700 Training Loss: 1.6837074756622314
# Validation loss: 1.3358982801437378
# Step: 2800 Training Loss: 1.5885881185531616
# Validation loss: 1.3605228662490845
# Step: 2900 Training Loss: 1.3164305686950684
# Validation loss: 1.5972082614898682
# Step: 3000 Training Loss: 1.5704785585403442
# Validation loss: 1.4182422161102295
# Step: 3100 Training Loss: 1.4812498092651367
# Validation loss: 1.4573439359664917
# Step: 3200 Training Loss: 1.4016104936599731
# Validation loss: 1.3759088516235352
# Step: 3300 Training Loss: 1.5572175979614258
# Validation loss: 1.5610185861587524
# Step: 3400 Training Loss: 1.495825171470642
# Validation loss: 1.4811028242111206
# Step: 3500 Training Loss: 1.3033087253570557
# Validation loss: 1.250376582145691
# Step: 3600 Training Loss: 1.4363694190979004
# Validation loss: 1.417945146560669
# Step: 3700 Training Loss: 1.3237409591674805
# Validation loss: 1.406834602355957
# Step: 3800 Training Loss: 1.4380675554275513
# Validation loss: 1.482763648033142
# Step: 3900 Training Loss: 1.4560565948486328
# Validation loss: 1.3958379030227661
# Step: 4000 Training Loss: 1.369875431060791
# Validation loss: 1.1438804864883423
# Step: 4100 Training Loss: 1.4118155241012573
# Validation loss: 1.3138008117675781
# Step: 4200 Training Loss: 1.4527891874313354
# Validation loss: 1.3024123907089233
# Step: 4300 Training Loss: 1.4970011711120605
# Validation loss: 1.319117784500122
# Step: 4400 Training Loss: 1.3780341148376465
# Validation loss: 1.3163743019104004
# Step: 4500 Training Loss: 1.2432533502578735
# Validation loss: 1.2868918180465698
# Step: 4600 Training Loss: 1.3957736492156982
# Validation loss: 1.3236204385757446
# Step: 4700 Training Loss: 1.4950553178787231
# Validation loss: 1.421668529510498
# Step: 4800 Training Loss: 1.4194955825805664
# Validation loss: 1.3262317180633545
# Step: 4900 Training Loss: 1.3967984914779663
# Validation loss: 1.369861125946045
# Step: 5000 Training Loss: 1.4112932682037354
# Validation loss: 1.239026427268982
# Step: 5100 Training Loss: 1.3510196208953857
# Validation loss: 1.299689769744873
# Step: 5200 Training Loss: 1.3385674953460693
# Validation loss: 1.4060883522033691
# Step: 5300 Training Loss: 1.3629833459854126
# Validation loss: 1.4713799953460693
# Step: 5400 Training Loss: 1.4302613735198975
# Validation loss: 1.4592275619506836
# Step: 5500 Training Loss: 1.4779614210128784
# Validation loss: 1.2807896137237549
# Step: 5600 Training Loss: 1.3062119483947754
# Validation loss: 1.2260023355484009
# Step: 5700 Training Loss: 1.3546994924545288
# Validation loss: 1.3071134090423584
# Step: 5800 Training Loss: 1.4415496587753296
# Validation loss: 1.3782559633255005
# Step: 5900 Training Loss: 1.1884385347366333
# Validation loss: 1.2336242198944092
# Step: 6000 Training Loss: 1.2453817129135132
# Validation loss: 1.2803659439086914
# Step: 6100 Training Loss: 1.3142718076705933
# Validation loss: 1.3757773637771606
# Step: 6200 Training Loss: 1.4302161931991577
# Validation loss: 1.1558914184570312
# Step: 6300 Training Loss: 1.259110450744629
# Validation loss: 1.2375421524047852
# Step: 6400 Training Loss: 1.2699477672576904
# Validation loss: 1.221677541732788
# Step: 6500 Training Loss: 1.3774670362472534
# Validation loss: 1.1690213680267334
# Step: 6600 Training Loss: 1.2611290216445923
# Validation loss: 1.231316089630127
# Step: 6700 Training Loss: 1.1664574146270752
# Validation loss: 1.0730801820755005
# Step: 6800 Training Loss: 1.211079716682434
# Validation loss: 1.2144715785980225
# Step: 6900 Training Loss: 1.3815630674362183
# Validation loss: 1.2371163368225098
# Step: 7000 Training Loss: 1.460456371307373
# Validation loss: 1.329628348350525
# Step: 7100 Training Loss: 1.3046221733093262
# Validation loss: 1.203493595123291
# Step: 7200 Training Loss: 1.3330847024917603
# Validation loss: 1.255791425704956
# Step: 7300 Training Loss: 1.3338046073913574
# Validation loss: 1.4191944599151611
# Step: 7400 Training Loss: 1.337660551071167
# Validation loss: 1.3593655824661255
# Step: 7500 Training Loss: 1.325313687324524
# Validation loss: 1.264481782913208
# Step: 7600 Training Loss: 1.2269865274429321
# Validation loss: 1.229736328125
# Step: 7700 Training Loss: 1.167639970779419
# Validation loss: 1.1161260604858398
# Step: 7800 Training Loss: 1.1997017860412598
# Validation loss: 1.3171364068984985
# Step: 7900 Training Loss: 1.3667563199996948
# Validation loss: 1.428452968597412
# Step: 8000 Training Loss: 1.294226050376892
# Validation loss: 1.206735372543335
# Step: 8100 Training Loss: 1.2957005500793457
# Validation loss: 1.179505467414856
# Step: 8200 Training Loss: 1.3199084997177124
# Validation loss: 1.0777407884597778
# Step: 8300 Training Loss: 1.2704989910125732
# Validation loss: 1.1530518531799316
# Step: 8400 Training Loss: 1.2625360488891602
# Validation loss: 1.2342462539672852
# Step: 8500 Training Loss: 1.2633183002471924
# Validation loss: 1.2541946172714233
# Step: 8600 Training Loss: 1.4116153717041016
# Validation loss: 1.1044107675552368
# Step: 8700 Training Loss: 1.1672065258026123
# Validation loss: 1.2132117748260498
# Step: 8800 Training Loss: 1.3431345224380493
# Validation loss: 1.0136845111846924
# Step: 8900 Training Loss: 1.181999683380127
# Validation loss: 1.219705581665039
# Step: 9000 Training Loss: 1.167588710784912
# Validation loss: 1.2816277742385864
# Step: 9100 Training Loss: 1.2083616256713867
# Validation loss: 1.0825366973876953
# Step: 9200 Training Loss: 1.191263198852539
# Validation loss: 1.1785424947738647
# Step: 9300 Training Loss: 1.2642157077789307
# Validation loss: 1.1702699661254883
# Step: 9400 Training Loss: 1.370714783668518
# Validation loss: 1.1260921955108643
# Step: 9500 Training Loss: 1.3295657634735107
# Validation loss: 1.1380066871643066
# Step: 9600 Training Loss: 1.2889622449874878
# Validation loss: 1.2094484567642212
# Step: 9700 Training Loss: 1.3614270687103271
# Validation loss: 1.2983243465423584
# Step: 9800 Training Loss: 1.3025457859039307
# Validation loss: 0.9861634969711304
# Step: 9900 Training Loss: 1.271720290184021
# Validation loss: 1.0309544801712036
# Step: 10000 Training Loss: 1.164172649383545
# Validation loss: 1.2548030614852905
# Step: 10100 Training Loss: 1.4421488046646118
# Validation loss: 1.1982026100158691
# Step: 10200 Training Loss: 1.0783963203430176
# Validation loss: 1.238322138786316
# Step: 10300 Training Loss: 1.3558107614517212
# Validation loss: 1.2686346769332886
# Step: 10400 Training Loss: 1.2344682216644287
# Validation loss: 1.2439484596252441
# Step: 10500 Training Loss: 1.380629301071167
# Validation loss: 1.2357308864593506
# Step: 10600 Training Loss: 1.1497927904129028
# Validation loss: 1.1185147762298584
# Step: 10700 Training Loss: 1.2471654415130615
# Validation loss: 1.320839285850525
# Step: 10800 Training Loss: 1.197699785232544
# Validation loss: 1.244925856590271
# Step: 10900 Training Loss: 1.2202260494232178
# Validation loss: 1.148945689201355
# Step: 11000 Training Loss: 1.3003543615341187
# Validation loss: 1.2689199447631836
# Step: 11100 Training Loss: 1.2392665147781372
# Validation loss: 1.1949280500411987
# Step: 11200 Training Loss: 1.3207546472549438
# Validation loss: 1.1927767992019653
# Step: 11300 Training Loss: 1.3408986330032349
# Validation loss: 1.1611251831054688
# Step: 11400 Training Loss: 1.232330560684204
# Validation loss: 1.2104158401489258
# Step: 11500 Training Loss: 1.1924281120300293
# Validation loss: 1.1290854215621948
# Step: 11600 Training Loss: 1.1786481142044067
# Validation loss: 1.3784735202789307
# Step: 11700 Training Loss: 1.2947511672973633
# Validation loss: 1.1943310499191284
# Step: 11800 Training Loss: 1.2006661891937256
# Validation loss: 1.1157728433609009
# Step: 11900 Training Loss: 1.0373249053955078
# Validation loss: 1.00269615650177
# Step: 12000 Training Loss: 1.0787630081176758
# Validation loss: 1.0684332847595215
# Step: 12100 Training Loss: 1.1654878854751587
# Validation loss: 1.2483983039855957
# Step: 12200 Training Loss: 1.2084797620773315
# Validation loss: 1.0861444473266602
# Step: 12300 Training Loss: 1.1702349185943604
# Validation loss: 1.249423861503601
# Step: 12400 Training Loss: 1.2315329313278198
# Validation loss: 1.246239423751831
# Step: 12500 Training Loss: 1.282354474067688
# Validation loss: 1.1971755027770996
# Step: 12600 Training Loss: 1.3004791736602783
# Validation loss: 1.1113828420639038
# Step: 12700 Training Loss: 1.2124674320220947
# Validation loss: 1.1609325408935547
# Step: 12800 Training Loss: 1.0899256467819214
# Validation loss: 1.2972408533096313
# Step: 12900 Training Loss: 1.1406760215759277
# Validation loss: 1.1751819849014282
# Step: 13000 Training Loss: 1.2409590482711792
# Validation loss: 1.2746574878692627
# Step: 13100 Training Loss: 1.217305064201355
# Validation loss: 1.0888186693191528
# Step: 13200 Training Loss: 1.1635432243347168
# Validation loss: 1.1296143531799316
# Step: 13300 Training Loss: 1.3803266286849976
# Validation loss: 1.1124018430709839
# Step: 13400 Training Loss: 1.3204866647720337
# Validation loss: 1.2316980361938477
# Step: 13500 Training Loss: 1.1621854305267334
# Validation loss: 1.2015559673309326
# Step: 13600 Training Loss: 1.1207417249679565
# Validation loss: 1.130892276763916
# Step: 13700 Training Loss: 1.2501012086868286
# Validation loss: 1.2337597608566284
# Step: 13800 Training Loss: 1.1266939640045166
# Validation loss: 1.0148171186447144
# Step: 13900 Training Loss: 1.1497280597686768
# Validation loss: 0.9476011395454407
# Step: 14000 Training Loss: 1.2032504081726074
# Validation loss: 1.217943787574768
# Step: 14100 Training Loss: 1.2984799146652222
# Validation loss: 1.024725317955017
# Step: 14200 Training Loss: 1.250278115272522
# Validation loss: 1.2250198125839233
# Step: 14300 Training Loss: 1.160537600517273
# Validation loss: 1.2450774908065796
# Step: 14400 Training Loss: 1.1198631525039673
# Validation loss: 1.2092242240905762
# Step: 14500 Training Loss: 1.118961215019226
# Validation loss: 1.253979206085205
# Step: 14600 Training Loss: 1.289383053779602
# Validation loss: 1.120624303817749
# Step: 14700 Training Loss: 1.1360822916030884
# Validation loss: 1.0808782577514648
# Step: 14800 Training Loss: 1.2687675952911377
# Validation loss: 1.1341991424560547
# Step: 14900 Training Loss: 1.2065905332565308
# Validation loss: 1.1034860610961914
# Step: 15000 Training Loss: 1.2070271968841553
# Validation loss: 1.1286725997924805
# Step: 15100 Training Loss: 1.1829591989517212
# Validation loss: 1.1645941734313965
# Step: 15200 Training Loss: 1.344368815422058
# Validation loss: 1.3286069631576538
# Step: 15300 Training Loss: 1.146748661994934
# Validation loss: 1.1333978176116943
# Step: 15400 Training Loss: 1.1934107542037964
# Validation loss: 1.0859477519989014
# Step: 15500 Training Loss: 1.2243211269378662
# Validation loss: 1.1093838214874268
# Step: 15600 Training Loss: 1.2950152158737183
# Validation loss: 0.9982107877731323
# Step: 15700 Training Loss: 1.191076397895813
# Validation loss: 1.180912971496582
# Step: 15800 Training Loss: 1.1219345331192017
# Validation loss: 1.2118254899978638
# Step: 15900 Training Loss: 1.2615026235580444
# Validation loss: 1.2279627323150635
# Step: 16000 Training Loss: 1.3250186443328857
# Validation loss: 1.0947113037109375
# Step: 16100 Training Loss: 1.2150366306304932
# Validation loss: 1.0735373497009277
# Step: 16200 Training Loss: 1.1646387577056885
# Validation loss: 1.1191972494125366
# Step: 16300 Training Loss: 1.095653772354126
# Validation loss: 1.067230463027954
# Step: 16400 Training Loss: 1.2343924045562744
# Validation loss: 1.0591630935668945
# Step: 16500 Training Loss: 1.283738374710083
# Validation loss: 1.1575090885162354
# Step: 16600 Training Loss: 1.2869226932525635
# Validation loss: 0.9903496503829956
# Step: 16700 Training Loss: 1.248321533203125
# Validation loss: 0.9442402720451355
# Step: 16800 Training Loss: 1.265647053718567
# Validation loss: 1.1229851245880127
# Step: 16900 Training Loss: 1.211205005645752
# Validation loss: 1.1187126636505127
# Step: 17000 Training Loss: 1.0922352075576782
# Validation loss: 1.2494863271713257
# Step: 17100 Training Loss: 1.2249993085861206
# Validation loss: 1.1295980215072632
# Step: 17200 Training Loss: 1.2953088283538818
# Validation loss: 1.0917094945907593
# Step: 17300 Training Loss: 1.1602150201797485
# Validation loss: 1.1673115491867065
# Step: 17400 Training Loss: 1.1397409439086914
# Validation loss: 1.112732172012329
# Step: 17500 Training Loss: 1.2414379119873047
# Validation loss: 1.1231341361999512
# Step: 17600 Training Loss: 1.195234775543213
# Validation loss: 1.1682554483413696
# Step: 17700 Training Loss: 1.249992847442627
# Validation loss: 1.1077466011047363
# Step: 17800 Training Loss: 1.254770278930664
# Validation loss: 1.3083877563476562
# Step: 17900 Training Loss: 1.1281729936599731
# Validation loss: 1.1002339124679565
# Step: 18000 Training Loss: 1.2601364850997925
# Validation loss: 1.0433688163757324
# Step: 18100 Training Loss: 1.2009119987487793
# Validation loss: 1.086487054824829
# Step: 18200 Training Loss: 1.1330859661102295
# Validation loss: 1.027819275856018
# Step: 18300 Training Loss: 1.1078128814697266
# Validation loss: 1.0631725788116455
# Step: 18400 Training Loss: 1.122658610343933
# Validation loss: 1.1787364482879639
# Step: 18500 Training Loss: 1.2853221893310547
# Validation loss: 1.111545443534851
# Step: 18600 Training Loss: 1.129075527191162
# Validation loss: 1.2606029510498047
# Step: 18700 Training Loss: 1.274482011795044
# Validation loss: 0.9916945099830627
# Step: 18800 Training Loss: 1.250532627105713
# Validation loss: 1.0277348756790161
# Step: 18900 Training Loss: 1.2565354108810425
# Validation loss: 1.0323001146316528
# Step: 19000 Training Loss: 1.2545806169509888
# Validation loss: 1.0632023811340332
# Step: 19100 Training Loss: 1.2706925868988037
# Validation loss: 0.9430010318756104
# Step: 19200 Training Loss: 1.2067145109176636
# Validation loss: 1.146089792251587
# Step: 19300 Training Loss: 1.102518916130066
# Validation loss: 0.9247965216636658
# Step: 19400 Training Loss: 1.1417090892791748
# Validation loss: 1.1017520427703857
# Step: 19500 Training Loss: 1.2145649194717407
# Validation loss: 1.0705082416534424
# Step: 19600 Training Loss: 1.1452922821044922
# Validation loss: 1.0996863842010498
# Step: 19700 Training Loss: 1.1157828569412231
# Validation loss: 0.9807829260826111
# Step: 19800 Training Loss: 1.1052404642105103
# Validation loss: 1.0225468873977661
# Step: 19900 Training Loss: 1.3343111276626587
# Validation loss: 1.018877387046814

# %%
model_path = os.path.join(data_path, "english_tiny_stories_6layers.pth")
torch.save(model, model_path)

# %%
starting_tokens = 'Alice lost her chicken. She went outside to look for it. But it was dark.'
encoded_start = tokenizer.encode(starting_tokens.lower())
encoded_start.pop(-1)
len_starting_tokens = len(encoded_start)

idx = torch.tensor(encoded_start).reshape(1, len_starting_tokens).to(device)
model.eval()
N_SAMPLES = 20
for _ in range(N_SAMPLES):
    generation = model.generate(idx, max_new_tokens=2000, temperature=0.7, stop_token=True)[0].tolist()
    story = tokenizer.decode(generation, skip_special_tokens=False)

    print('Story ', _ + 1, ':')
    print(story)
    print('\n')
# Out:
# Story  1 :
# [CLS] alice lost her chicken. she went outside to look for it. but it was dark. alice saw a butterfly. she wanted it so she slowly moved the butterfly back to her nest. but the butterfly was too fast. she flew away with the butterfly. alice was sad. she wanted her chicken back. she looked around and spotted a group of birds. they were all alone. alice was so happy! she stopped flying and looked at the butterflies. she smiled and said, " hello! " the butterflies nodded and flew away. alice felt so happy and strong. she thanked the butterflies and headed back home. [SEP]
#
#
# Story  2 :
# [CLS] alice lost her chicken. she went outside to look for it. but it was dark. suddenly, she saw something that made her way back home. it was a big, beautiful horse. she was so happy to find it. alice was even more excited. she had never seen a horse before. she said to the horse, " hello! let's keep the horse and take it home. " the horse was so happy to see alice. they put the horse in a box and the horse in the box. the horse looked at alice and said, " hello, alice! i'm new here. i'm new here to help. " alice smiled and said, " yes, i'm molly. i'm so happy to have new friends. " the horse said, " thank you, alice! i'm so happy to help you. " they hugged the horse and went off to explore the meadow. [SEP]
#
#
# Story  3 :
# [CLS] alice lost her chicken. she went outside to look for it. but it was dark. alice looked for it, but couldn't find it. she felt very sad. suddenly, she saw something in the sky. it was a bird. the bird was singing a happy song. alice asked, " what are you doing? " the bird replied, " i'm lost. can you help me find my way home? " alice smiled, and the bird was so happy. together, alice and the bird walked through the sky. they saw many animals. they were all singing and talking. alice was so happy. she never forgot to take care of the bird. [SEP]
#
#
# Story  4 :
# [CLS] alice lost her chicken. she went outside to look for it. but it was dark. alice was feeling scared. she looked everywhere but could not find it. as she walked, she saw a big tree. she climbed the tree and saw a bird. the bird had a nest with eggs in its beak. it was singing a happy song. alice wanted to sing a song so she could sing with the bird. the song was so beautiful. alice thought that she was trying to sing with the bird. she sang a song for the bird. the bird heard the song and flew down. it said hello back to alice. alice was so happy that she sang along with the bird. she thanked it for helping her. alice smiled at the bird and they both sang together in the sunshine. [SEP]
#
#
# Story  5 :
# [CLS] alice lost her chicken. she went outside to look for it. but it was dark. she looked in the mirror, but she couldn't find it. " where is my horse? " she asked. suddenly, alice saw a little girl. she had the horse in her eye. " i lost my horse! " she said. the little girl smiled and said " thank you. " she ran around the garden, looking for her horse. she left the room. but before they left, alice found out that the horse was a threat. it was not a threat. it was a giant family of animals! they were so friendly and friendly. alice was so happy she had found her horse. she had a new friend and a new friend. [SEP]
#
#
# Story  6 :
# [CLS] alice lost her chicken. she went outside to look for it. but it was dark. alice was sad. then she saw a big, shiny pony in the sky! she picked it up and held it in her hand. it was so pretty. she held it close and she felt like a princess. the pony flew around her and said, " hello, i'm robin. can i stay here? " alice was so happy to have a new friend. she said, " yes! i'm alice. i am here to help you. " ashley and robin played together all day. they had so much fun. when it was time to go home, alice said goodbye to josh and left the sky. she thanked robin for the help and they both stepped back home. alice felt lucky to have a new friend and a wonderful friend. [SEP]
#
#
# Story  7 :
# [CLS] alice lost her chicken. she went outside to look for it. but it was dark. she felt scared and started to cry. suddenly, she heard a loud noise. it was a cat! the cat said to alice : " don't be scared. i'm here to help you find my chicken! " alice was so happy and she hugged the cat. the cat wasn't mad ; it just wanted to help alice find her egg. the cat and alice looked all around the house. then, she saw a yellow egg on the ground. it was red and bright. the cat said : " let's take it home together! " the cat agreed and they both started to take it home. the cat was so happy and they hugged. the cat had been so cute to see her egg. [SEP]
#
#
# Story  8 :
# [CLS] alice lost her chicken. she went outside to look for it. but it was dark. she looked around, but it was nowhere to be found. she was disappointed! alice's mom saw her and asked, " what are you doing, alice? " alice replied, " i found a gray chicken! " her mom smiled and said, " that's a very special chicken, " alice replied, " can i keep it? " her mom said, " yes, you can. it's very special. " alice was so happy. she couldn't wait to show her mom the gray chicken. she ran inside and found out it was so special. she was so excited that she ran outside to show her mom. together, they went to the house and found a beautiful garden. it was so beautiful. alice couldn't believe it! she was so happy! [SEP]
#
#
# Story  9 :
# [CLS] alice lost her chicken. she went outside to look for it. but it was dark. alice got lost. she was too scared to go home, so she started to cry. just then, a friendly dog came running up to her. the dog said, " i can help you find your chicken! " the dog kneeled alice's hand and they looked and looked, but they couldn't find it. the dog wanted to help alice. the dog let alice know why she was crying. alice was so happy that she stopped crying. they looked for the chicken everywhere. the dog quickly found it in a nearby park. it was a big, warm field. alice and the dog became friends. they played in the field until it was time to go home. [SEP]
#
#
# Story  10 :
# [CLS] alice lost her chicken. she went outside to look for it. but it was dark. alice was feeling a bit scared. she started to cry. her mom heard her and ran outside. she saw alice on a bench. she asked alice why she was crying. alice said she was lost and she had to go home. her mom hugged her and said, " don't worry, let's go find your chicken. " they walked and walked until they came to a spot where they found the chicken. alice was so happy to see her chicken again. she hugged her mom and said, " thank you! " then they went back to their home to have a delicious dinner. [SEP]
#
#
# Story  11 :
# [CLS] alice lost her chicken. she went outside to look for it. but it was dark. she looked around the trees and under benches. she looked in the sandbox, but couldn't find it. she was so sad and started to cry. suddenly, she heard a voice. it said, " don't be afraid. i can help you find your chicken. " alice looked around to see anyone who was talking. she saw a little girl. she said, " i found this chicken! it was hiding somewhere. " the little girl smiled and said, " thank you! " they both laughed and hugged. alice felt much better. she thanked the little girl. she said, " maybe i will find it later. " [SEP]
#
#
# Story  12 :
# [CLS] alice lost her chicken. she went outside to look for it. but it was dark. alice felt so sad. she wanted to find her chicken. she looked and looked, but she could not see it. " where is her chicken? " she asked herself. suddenly, she heard a voice behind her. it was her friend, jack. jack had a big, fluffy teddy bear. " what are you doing here? " asked alice. " i'm searching for your chicken. " jack smiled. " that's nice! " he said. " " do you want to help me find it? " alice smiled. she said, " yes, i would love to help you! " they looked for the chicken everywhere. they looked under benches and behind trees. they still could not find it. alice was very sad. she had lost her chicken. she had lost it. [SEP]
#
#
# Story  13 :
# [CLS] alice lost her chicken. she went outside to look for it. but it was dark. she saw it on the ground. she bent down to pick it up. she wiped it with a soft cloth. she was about to give up when she heard a voice. " who are you? " asked the voice from the voice. alice looked around and saw a little mouse. the mouse looked at alice and replied, " i am mimi and i can't find my way home. " alice nodded her head. mimi said, " don't worry! i will help you find your home. " so, they both started to look for mimi's home. they looked in the grass and by the trees, they found mimi's home. lucy was so happy to have her back. she said, " thank you, mimi! " with mimi's help, she flew up to her nest and knocked on the softest of the farm. the end. [SEP]
#
#
# Story  14 :
# [CLS] alice lost her chicken. she went outside to look for it. but it was dark. she began to cry. suddenly, she heard a loud noise. she saw a huge truck and it was coming down the road. alice was scared but she was also excited. she quickly ran away from the truck and followed a long road. she couldn't find the chicken. she was too nervous to cry. suddenly, the truck drove away from the road. alice was relieved and she thanked the truck driver. she was no longer worried. then she heard a noise coming from the road. it was a man! he was wearing a big hat and a big red coat. he was wearing a hat and a coat and a hat. " welcome to my truck, " he said. alice felt so relieved and excited. she had never seen an old truck before. the man smiled and said, " come with me. i have his own truck for you! " it was much better than she had lost it. alice was so happy and she thanked the man. she never forgot to take care of her farm. [SEP]
#
#
# Story  15 :
# [CLS] alice lost her chicken. she went outside to look for it. but it was dark. she was very sad. suddenly, she saw a big ball. it was red and shiny. she picked it up and looked at it. it was a big, furry animal! it was so cute. she picked it up and took it home. she was so happy to have found her new friend. she even put it near her barn. she was so excited to show it to her mom. when she showed it to her mom, she said it was a new friend. she smiled and said it was a toy. she asked if she wanted to play with it. her mom said yes, and they went outside to play with the new toy. they had a wonderful day together. [SEP]
#
#
# Story  16 :
# [CLS] alice lost her chicken. she went outside to look for it. but it was dark. she was getting lost. suddenly, she heard a sound. it was a loud noise. it was a dog. the dog was barking and it seemed scared. alice was so scared that she ran back home. she was so relieved to have found her chicken! she picked it up and put it in a drawer. she carefully placed it in the box. the dog seemed to like the box. alice felt so relieved and happy. she had found her chicken! [SEP]
#
#
# Story  17 :
# [CLS] alice lost her chicken. she went outside to look for it. but it was dark. she walked and walked, until she came across a big tree. she wanted to get her chicken, but she was too small. she started to worry. " i can't get my chicken! " asked alice. the chicken didn't answer. then alice had an idea. she found a long stick and used it to get her chicken down. she gently scooped her chicken down and put it back in the ground. she was very happy and grateful to have her chicken. alice smiled and hugged the chicken. she was so happy to see her chicken again. [SEP]
#
#
# Story  18 :
# [CLS] alice lost her chicken. she went outside to look for it. but it was dark. she started to cry. she didn't know where it was. suddenly, alice heard a loud noise. she looked up and saw a big truck. she was so excited to see the truck again. she wanted to show everyone where the truck was going. but when she opened the door, she saw a little girl. she was wearing a pink dress and her black dress. alice was so excited. she approached them and said hello. the little girl smiled back. she said hello back and they became friends. she loved her chicken and wanted to take care of it. alice was so happy again. she hugged the little girl and they hugged her. it was a fun day! [SEP]
#
#
# Story  19 :
# [CLS] alice lost her chicken. she went outside to look for it. but it was dark. she looked under the trees and in the bushes. suddenly, she heard a voice calling out, " hey, why are you hiding? " alice turned around and saw a tiny bird. the bird said, " i lost my egg. i am lost. " alice laughed. " don't worry, " she said. " we will find your egg together. " alice and the bird searched and searched, until finally they found it. the bird was very happy. he said, " thank you, alice! " they both smiled and went back to the car, far away. [SEP]
#
#
# Story  20 :
# [CLS] alice lost her chicken. she went outside to look for it. but it was dark. alice didn't know what to do. she was feeling sad and scared. suddenly, she saw a little bird. the bird had a message in its beak! it said : " i lost my chicken! " alice was so happy to see her chicken! she gave it a big hug. the bird smiled, and alice felt better. she thanked the bird for helping her find her chicken. alice and the bird became good friends. the little bird thanked alice and flew away. [SEP]
